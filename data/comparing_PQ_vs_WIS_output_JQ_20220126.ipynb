# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Reading in the original data

# %%
path = "pairwiseMetrics_cancer_non-cancer_s1.txt.gz"

# %%
names = ["Chromosome", "Start", "End", "MaxDiffState", "Distance", "Sign", "Pval", "MHPval"]

# %%
pairwiseMetrics = pd.read_table(path, header=None, sep="\t", names=names).astype({"Chromosome": str, "Start": np.int32, "End": np.int32, "MaxDiffState": str, "Distance": np.float32, "Sign": str, "Pval": np.float32, "MHPval": np.float32})

# %%
originalExemplars = pairwiseMetrics.iloc[(-pairwiseMetrics["Distance"].abs()).argsort()].head(100)

# %% [markdown]
# ### Reading in the clumped data

# %%
names = ["Chromosome", "Start", "End", "MaxDiffState", "Distance", "Sign", "Pval", "MHPval", "Dummy"]

# %%
clumpedPath = "../results/highValueData.txt.gz"

# %%
clumpedDF = pd.read_table(clumpedPath, header=None, sep="\t", names=names).astype({"Chromosome": str, "Start": np.int32, "End": np.int32, "MaxDiffState": str, "Distance": np.float32, "Sign": str, "Pval": np.float32, "MHPval": np.float32, "Dummy": str})

# %%
clumpedExemplars = clumpedDF.iloc[(-clumpedDF["Distance"].abs()).argsort()].head(100)

# %% [markdown]
# ### Reading in the evenly spread data

# %%
spreadPath = "../results/flattenedData.txt.gz"

# %%
spreadDF = pd.read_table(spreadPath, header=None, sep="\t", names=names).astype({"Chromosome": str, "Start": np.int32, "End": np.int32, "MaxDiffState": str, "Distance": np.float32, "Sign": str, "Pval": np.float32, "MHPval": np.float32, "Dummy": str})

# %%
spreadExemplars = spreadDF.iloc[(-spreadDF["Distance"].abs()).argsort()].head(100)

# %% [markdown]
# ### Reading in PQ clumped

# %%
clumpedPQPath = "pq.bed.clumped"

# %%
clumpedPQDF = pd.read_table(clumpedPQPath, header=None, sep="\t", names=names).astype({"Chromosome": str, "Start": np.int32, "End": np.int32, "MaxDiffState": str, "Distance": np.float32, "Sign": str, "Pval": np.float32, "MHPval": np.float32, "Dummy": str})

# %%
clumpedPQExemplars = clumpedPQDF.iloc[(-clumpedPQDF["Distance"].abs()).argsort()].head(100)

# %% [markdown]
# ### Reading in WIS clumped

# %%
clumpedWISPath = "wis.bed.clumped"

# %%
clumpedWISDF = pd.read_table(clumpedWISPath, header=None, sep="\t", names=names).astype({"Chromosome": str, "Start": np.int32, "End": np.int32, "MaxDiffState": str, "Distance": np.float32, "Sign": str, "Pval": np.float32, "MHPval": np.float32, "Dummy": str})

# %%
clumpedWISExemplars = clumpedWISDF.iloc[(-clumpedWISDF["Distance"].abs()).argsort()].head(100)

# %% [markdown]
# ### Reading in PQ Spread

# %%
spreadPQPath = "pq.bed.evenSpacing"

# %%
spreadPQDF = pd.read_table(spreadPQPath, header=None, sep="\t", names=names).astype({"Chromosome": str, "Start": np.int32, "End": np.int32, "MaxDiffState": str, "Distance": np.float32, "Sign": str, "Pval": np.float32, "MHPval": np.float32, "Dummy": str})

# %%
spreadPQExemplars = spreadPQDF.iloc[(-spreadPQDF["Distance"].abs()).argsort()].head(100)

# %% [markdown]
# ### Reading in WIS spread

# %%
spreadWISPath = "wis.bed.evenSpacing"

# %%
spreadWISDF = pd.read_table(spreadWISPath, header=None, sep="\t", names=names).astype({"Chromosome": str, "Start": np.int32, "End": np.int32, "MaxDiffState": str, "Distance": np.float32, "Sign": str, "Pval": np.float32, "MHPval": np.float32, "Dummy": str})

# %%
spreadWISExemplars = spreadWISDF.iloc[(-spreadWISDF["Distance"].abs()).argsort()].head(100)

# %% [markdown]
# ### Comparing Original vs PQ vs WIS clumped

# %%
clumpedExemplars.head(10)
# Out:
#          Chromosome      Start        End MaxDiffState   Distance Sign  \
# 13832371      chr20   47902600   47902800            8  56.064678    +
# 12707236      chr17   41276800   41277000            1  55.905739    +
# 12582589      chr17   16347400   16347600            8  55.137058    +
# 12582576      chr17   16344800   16345000            8  54.722752    +
# 13832373      chr20   47903000   47903200            8  54.082130    +
# 8393897        chr9  139620200  139620400            8  53.253578    +
# 8393890        chr9  139618800  139619000            7  53.210369    +
# 13606034      chr20    2635200    2635400            8  53.081379    +
# 9455101       chr11   75113000   75113200            8  53.032398    +
# 8393903        chr9  139621400  139621600            4  52.780590    +
#
#              Pval   MHPval Dummy
# 13832371  0.00000  0.00869   nan
# 12707236  0.00000  0.00869   nan
# 12582589  0.00002  0.01020   nan
# 12582576  0.00000  0.00869   nan
# 13832373  0.00000  0.00869   nan
# 8393897   0.00000  0.00869   nan
# 8393890   0.00001  0.00897   nan
# 13606034  0.00000  0.00869   nan
# 9455101   0.00000  0.00869   nan
# 8393903   0.00000  0.00869   nan

# %%
clumpedPQExemplars.head(10)
# Out:
#        Chromosome      Start        End MaxDiffState   Distance Sign     Pval  \
# 99058       chr17   41276800   41277000            1  55.905739    +  0.00000
# 95717       chr17   16344800   16345000            8  54.722752    +  0.00000
# 247604       chrX   69510200   69510400            1  54.221569    +  0.00000
# 244471       chr9  139620200  139620400            8  53.253578    +  0.00000
# 143223      chr20    2635200    2635400            8  53.081379    +  0.00000
# 42699       chr11   75113000   75113200            8  53.032398    +  0.00000
# 95718       chr17   16347800   16348000            8  52.679951    +  0.00004
# 118151      chr19   42366400   42366600            8  52.148220    +  0.00000
# 226824       chr8   48872000   48872200            2  52.046761    -  0.00000
# 148588      chr20   47902200   47902400            8  51.112049    +  0.00000
#
#          MHPval Dummy
# 99058   0.00869     .
# 95717   0.00869     .
# 247604  0.00869     .
# 244471  0.00869     .
# 143223  0.00869     .
# 42699   0.00869     .
# 95718   0.01132     .
# 118151  0.00869     .
# 226824  0.00869     .
# 148588  0.00869     .

# %%
clumpedExemplars.iloc[0:10]
# Out:
#          Chromosome      Start        End MaxDiffState   Distance Sign  \
# 13832371      chr20   47902600   47902800            8  56.064678    +
# 12707236      chr17   41276800   41277000            1  55.905739    +
# 12582589      chr17   16347400   16347600            8  55.137058    +
# 12582576      chr17   16344800   16345000            8  54.722752    +
# 13832373      chr20   47903000   47903200            8  54.082130    +
# 8393897        chr9  139620200  139620400            8  53.253578    +
# 8393890        chr9  139618800  139619000            7  53.210369    +
# 13606034      chr20    2635200    2635400            8  53.081379    +
# 9455101       chr11   75113000   75113200            8  53.032398    +
# 8393903        chr9  139621400  139621600            4  52.780590    +
#
#              Pval   MHPval Dummy
# 13832371  0.00000  0.00869   nan
# 12707236  0.00000  0.00869   nan
# 12582589  0.00002  0.01020   nan
# 12582576  0.00000  0.00869   nan
# 13832373  0.00000  0.00869   nan
# 8393897   0.00000  0.00869   nan
# 8393890   0.00001  0.00897   nan
# 13606034  0.00000  0.00869   nan
# 9455101   0.00000  0.00869   nan
# 8393903   0.00000  0.00869   nan

# %%
clumpedDF.iloc[12707206:12707266]
# Out:
#          Chromosome     Start       End MaxDiffState   Distance Sign     Pval  \
# 12707206      chr17  41270800  41271000            6   0.687870    +  0.01399
# 12707207      chr17  41271000  41271200           11   0.563980    +  0.01908
# 12707208      chr17  41271200  41271400           18   0.423070    +  0.02896
# 12707209      chr17  41271400  41271600           11   0.592970    +  0.01768
# 12707210      chr17  41271600  41271800            6   0.899190    +  0.00892
# 12707211      chr17  41271800  41272000            6   1.153180    +  0.00567
# 12707212      chr17  41272000  41272200            6   1.153180    +  0.00567
# 12707213      chr17  41272200  41272400            6   1.018850    +  0.00714
# 12707214      chr17  41272400  41272600            6   1.049130    +  0.00677
# 12707215      chr17  41272600  41272800            6   1.258820    +  0.00480
# 12707216      chr17  41272800  41273000            6   1.258820    +  0.00480
# 12707217      chr17  41273000  41273200            6   1.258820    +  0.00480
# 210768  0.00869     .
# 211113  0.93879     .
# 206607  0.00900     .
# 212590  0.00869     .
# 209424  0.00869     .
# 203945  0.23748     .
# 204434  0.00869     .

# %%
clumpedWISExemplars.head(20)
# Out:
#        Chromosome      Start        End MaxDiffState   Distance Sign     Pval  \
# 247157       chrX   69510200   69510400            1  54.221569    +  0.00000
# 205663      chr17   16347800   16348000            8  52.679951    +  0.00004
# 205662      chr17   16343000   16343200            1  52.098240    +  0.00002
# 234026      chr20   47902200   47902400            8  51.112049    +  0.00000
# 228953      chr20    2637200    2637400            5  51.068390    -  0.00132
# 186265      chr15   30915800   30916000           18  50.822411    -  0.53935
# 114247       chr8   48869000   48869200            5  50.714809    +  0.00087
# 208617      chr17   41278600   41278800            4  50.058350    +  0.00031
# 228952      chr20    2632400    2632600            1  49.330719    +  0.00914
# 132410       chr9  139623000  139623200            1  47.772572    -  0.00095
# 225552      chr19   42363400   42363600            3  47.723850    +  0.00696
# 124815       chr9   36573600   36573800            1  47.405090    +  0.00000
# 31320        chr2  101619600  101619800            1  47.365040    +  0.00009
# 132409       chr9  139618400  139618600            5  46.460419    +  0.00002
# 225553      chr19   42368000   42368200            7  45.342388    +  0.00002
# 131824       chr9  136216800  136217000            8  43.856022    +  0.00000
# 104325       chr7  100798600  100798800            4  42.945400    -  0.00000
# 203333      chr16   89882600   89882800            1  42.253559    -  0.00000
# 234027      chr20   47906600   47906800            5  41.807388    +  0.00529
# 30186        chr2   85843800   85844000            2  41.513309    -  0.00000
#
#          MHPval Dummy
# 247157  0.00869     .
# 205663  0.01132     .
# 205662  0.01053     .
# 234026  0.00869     .
# 228953  0.03255     .
# 186265  0.93879     .
# 114247  0.02745     .
# 208617  0.01874     .
# 228952  0.07955     .
# 132410  0.02848     .
# 225552  0.06926     .
# 124815  0.00869     .
# 31320   0.01321     .
# 132409  0.01025     .
# 225553  0.01019     .
# 131824  0.00869     .
# 104325  0.00869     .
# 203333  0.00869     .
# 234027  0.06053     .
# 30186   0.00869     .

# %%
clumpedWISExemplars.head(10)
# Out:
#        Chromosome      Start        End MaxDiffState   Distance Sign     Pval  \
# 247157       chrX   69510200   69510400            1  54.221569    +  0.00000
# 205663      chr17   16347800   16348000            8  52.679951    +  0.00004
# 205662      chr17   16343000   16343200            1  52.098240    +  0.00002
# 234026      chr20   47902200   47902400            8  51.112049    +  0.00000
# 228953      chr20    2637200    2637400            5  51.068390    -  0.00132
# 186265      chr15   30915800   30916000           18  50.822411    -  0.53935
# 114247       chr8   48869000   48869200            5  50.714809    +  0.00087
# 208617      chr17   41278600   41278800            4  50.058350    +  0.00031
# 228952      chr20    2632400    2632600            1  49.330719    +  0.00914
# 132410       chr9  139623000  139623200            1  47.772572    -  0.00095
#
#          MHPval Dummy
# 247157  0.00869     .
# 205663  0.01132     .
# 205662  0.01053     .
# 234026  0.00869     .
# 228953  0.03255     .
# 186265  0.93879     .
# 114247  0.02745     .
# 208617  0.01874     .
# 228952  0.07955     .
# 132410  0.02848     .

# %% [markdown]
# ### Comparing Original vs PQ vs WIS spread

# %%
spreadExemplars.head(10)
# Out:
#          Chromosome      Start        End MaxDiffState   Distance Sign  Pval  \
# 13832374      chr20   47903200   47903400            8  57.402458    +   0.0
# 12582578      chr17   16345200   16345400            8  56.087971    +   0.0
# 12707236      chr17   41276800   41277000            1  55.905739    +   0.0
# 14752707       chrX   69510200   69510400            1  54.221569    +   0.0
# 8393897        chr9  139620200  139620400            8  53.253578    +   0.0
# 13606034      chr20    2635200    2635400            8  53.081379    +   0.0
# 9455101       chr11   75113000   75113200            8  53.032398    +   0.0
# 13509046      chr19   42366400   42366600            8  52.148220    +   0.0
# 7208336        chr8   48872000   48872200            2  52.046761    -   0.0
# 11691015      chr15   30918400   30918600            2  51.060848    -   0.0
#
#            MHPval Dummy
# 13832374  0.00869   nan
# 12582578  0.00869   nan
# 12707236  0.00869   nan
# 14752707  0.00869   nan
# 8393897   0.00869   nan
# 13606034  0.00869   nan
# 9455101   0.00869   nan
# 13509046  0.00869   nan
# 7208336   0.00869   nan
# 11691015  0.00869   nan

# %%
spreadPQExemplars.head(10)
# Out:
#        Chromosome      Start        End MaxDiffState   Distance Sign  Pval  \
# 148583      chr20   47903200   47903400            8  57.402458    +   0.0
# 95711       chr17   16345200   16345400            8  56.087971    +   0.0
# 99050       chr17   41276800   41277000            1  55.905739    +   0.0
# 247602       chrX   69510200   69510400            1  54.221569    +   0.0
# 244466       chr9  139620200  139620400            8  53.253578    +   0.0
# 143218      chr20    2635200    2635400            8  53.081379    +   0.0
# 42696       chr11   75113000   75113200            8  53.032398    +   0.0
# 118147      chr19   42366400   42366600            8  52.148220    +   0.0
# 226817       chr8   48872000   48872200            2  52.046761    -   0.0
# 74965       chr15   30918400   30918600            2  51.060848    -   0.0
#
#          MHPval Dummy
# 148583  0.00869     .
# 95711   0.00869     .
# 99050   0.00869     .
# 247602  0.00869     .
# 244466  0.00869     .
# 143218  0.00869     .
# 42696   0.00869     .
# 118147  0.00869     .
# 226817  0.00869     .
# 74965   0.00869     .

# %%
spreadWISExemplars.head(10)
# Out:
#        Chromosome      Start        End MaxDiffState   Distance Sign  Pval  \
# 234027      chr20   47903200   47903400            8  57.402458    +   0.0
# 205670      chr17   16345200   16345400            8  56.087971    +   0.0
# 208623      chr17   41276800   41277000            1  55.905739    +   0.0
# 247157       chrX   69510200   69510400            1  54.221569    +   0.0
# 132419       chr9  139620200  139620400            8  53.253578    +   0.0
# 228954      chr20    2635200    2635400            8  53.081379    +   0.0
# 153004      chr11   75113000   75113200            8  53.032398    +   0.0
# 225555      chr19   42366400   42366600            8  52.148220    +   0.0
# 114255       chr8   48872000   48872200            2  52.046761    -   0.0
# 186274      chr15   30918400   30918600            2  51.060848    -   0.0
#
#          MHPval Dummy
# 234027  0.00869     .
# 205670  0.00869     .
# 208623  0.00869     .
# 247157  0.00869     .
# 132419  0.00869     .
# 228954  0.00869     .
# 153004  0.00869     .
# 225555  0.00869     .
# 114255  0.00869     .
# 186274  0.00869     .
